# %%
# 29. Use the same population data as in the previous exercise.

# a) Create a new Pandas data frame where the first column is the year and other 142 columns are populations
# of all the countries in the data

import pandas as pd

# Read the CSV file
df = pd.read_csv("population.csv")

# Drop unnecessary columns if any (e.g., 'Unnamed: 0')
if 'Unnamed: 0' in df.columns:
    df = df.drop(columns='Unnamed: 0')

# df.head()
# lets's define unique countries name which is other column except first column which is year

# countries = df['country'].unique().tolist()

# countries

# let's define years

# years= df['year'].unique()

# years

# lets gets population of one country

# df[df['country'] == 'Sweden']['pop']

# define data frame which column year

# df_population = pd.DataFrame(years,columns = ['year'])

# display(df_population)

# for name in countries :
    # df_population[name] = df[df['country'] == name]['pop'].values

# display(df_population)

# Pivot the DataFrame to have years as rows and countries as columns
df_population = df.pivot(index='year', columns='country', values='pop')

# Drop the 'country' level from the columns
# df_population.columns = df_population.columns.droplevel()
# Reset index to have 'year' as a column
df_population = df_population.reset_index()

# Rename columns to remove multi-level headers (i.e., remove 'country' label)
# This removes the 'country' name from the columns
df_population.columns.name = None

# Display the resulting DataFrame
display(df_population)
# Out:
#     year  Afghanistan  Albania   Algeria    Angola  Argentina  Australia  \
# 0   1952      8425333  1282697   9279525   4232095   17876956    8691212
# 1   1957      9240934  1476505  10270856   4561361   19610538    9712569
# 2   1962     10267083  1728137  11000948   4826015   21283783   10794968
# 3   1967     11537966  1984060  12760499   5247469   22934225   11872264
# 4   1972     13079460  2263554  14760787   5894858   24779799   13177000
# 5   1977     14880372  2509048  17152804   6162675   26983828   14074100
# 6   1982     12881816  2780097  20033753   7016384   29341374   15184200
# 7   1987     13867957  3075321  23254956   7874230   31620918   16257249
# 8   1992     16317921  3326498  26298373   8735988   33958947   17481977
# 9   1997     22227415  3428038  29072015   9875024   36203463   18565243
# 10  2002     25268405  3508512  31287142  10866106   38331121   19546792
# 11  2007     31889923  3600523  33333216  12420476   40301927   20434176
#
# ...
